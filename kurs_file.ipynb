# %%
import numpy as np # бібліотека для роботи з масивами
import cv2 # бібліотека для роботи з комп'ютерним зором
from matplotlib import pyplot as plt # бібліотека для створення та відображення графіків

image_filenames = ['test/1.bmp', 'test/2.bmp', 'test/3.bmp', 'test/4.bmp'] # зображення класів розпізнавання
big_image = "test/intel.jpg" # велике зображення
class_names = ['A', 'B', 'C', 'D'] # назви класів
output_path = "classified_image.jpg" # Зберегти результуюче зображення
# Кольори для позначення кожного класу
# Червоний, Зелений, Блакитний, Пурпуровий, Білий
class_colors = [(255, 0, 0), (0, 255, 0), (0, 255, 255), (255, 0, 255), (255, 255, 255)]
class_block_size = 50 # розмір області класифікації
kulbak_lambda = 2

# головна функція класифікації
def startRecognition(big_image, class_images, class_colors, block_size):
    # відкриття та відображення великого зображення у вікні
    image = cv2.imread(big_image)
    # Конвертація в RGB для правильного відображення в matplotlib
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    fig, ax = plt.subplots(1)
    ax.set_title("Big image")
    ax.imshow(image)

    # Отримуємо значення кольорів для кожного класу
    pixel_values = extract_pixel_values(class_images)
    # Знаходимо оптимальне значення дельти
    delta = find_delta(pixel_values)

    # ініціалізуємо масив для бінарних матриць
    binary_matrices = []
    # ініціалізуємо масив для еталонних векторів
    etalon_vectors = []
    # Визначаємо значення для масиву контрольних допусків
    control_tolerance_vector = find_control_tolerance_vector(pixel_values[0])

    # Створюємо бінарні матриці для кожного класу та їх еталонні вектори
    for values in pixel_values:
        binary_matrix = create_binary_matrix(values, control_tolerance_vector, delta)
        binary_matrices.append(binary_matrix)
        etalon_vectors.append(create_etalon_vector(binary_matrix))

    # Знаходимо радіуси контейнерів для кожного класу
    radius = find_class_optimal_radius(etalon_vectors, binary_matrices)
    print("Optimal radius for 4 classes:", radius)

    # Починаємо розпізнавати фрагменти
    exam_algorithm(big_image, class_colors, block_size, delta, 
                   control_tolerance_vector, etalon_vectors, radius)

# Функція пошуку оптимальної дельти для СКД
def find_delta(pixel_values):
    # установлюємо початкове значення для delta
    optimal_delta = 0
    # установлюємо початкове значення для критерію
    best_criteria_value = 0
    # Масиви, які будуть використані для побудови графіка
    deltas = []
    criteria_values = []
    criteria_values_work_area = []

    print("Calculation of the optimal delta")

    # Перевіряємо дельту в діапазоні від 1 до 116
    for delta in range(1, 117):
        deltas.append(delta)
        print("For delta " + str(delta))
        # ініціалізуємо масив для бінарних матриць
        binary_matrices = []
        # ініціалізуємо масив для еталонних векторів
        etalon_vectors = []
        # шукаємо значення для масиву контрольних допусків
        control_tolerance_vector = find_control_tolerance_vector(pixel_values[0])

        # Створюємо бінарні матриці для кожного класу та їх еталонні вектори
        for values in pixel_values:
            binary_matrix = create_binary_matrix(values, control_tolerance_vector, delta)
            binary_matrices.append(binary_matrix)
            etalon_vectors.append(create_etalon_vector(binary_matrix))

        # Пошук класів сусідів
        neighbor_pairs = find_neighbors(etalon_vectors)
        # Пошук інформаційного критерію
        criteria_results = compute_criteria(etalon_vectors, binary_matrices, neighbor_pairs)

        # Перевіряємо наявність робочих областей
        working_area_values = [max([pair[0] for pair in result if pair[1]], default=0)
                               for result in criteria_results]

        # Обчислюємо середнє значення критерію та оновлюємо оптимальну дельту
        current_value = np.mean(working_area_values)
        if current_value > best_criteria_value:
            optimal_delta = delta
            best_criteria_value = current_value

        criteria_values.append(np.mean([max([pair[0] for pair in result], default=0)
                              for result in criteria_results]));
        criteria_values_work_area.append(current_value if current_value > 0 else -1);

        print("Delta | criteria value | criteria value in working area")
        print(delta, " | ", np.mean([max([pair[0] for pair in result], default=0)
                              for result in criteria_results]), " | ",
              current_value if current_value > 0 else -1)

    # Побудова графіка
    # Фільтрація значень
    filtered_criteria_values = [cv if cv >= 0 and not np.isinf(cv) else np.nan for cv in criteria_values]
    filtered_criteria_values_work_area = [cva if cva >= 0 and not np.isinf(cva) else np.nan for cva in criteria_values_work_area]

    # Створення маски для збігання значень
    overlap_exact = [
        cv if cv == cva and not (np.isnan(cv) or np.isnan(cva)) else np.nan
        for cv, cva in zip(filtered_criteria_values, filtered_criteria_values_work_area)
    ]

    plt.figure(figsize=(10, 6))
    
    # Заповнення області для Criteria Values
    plt.fill_between(deltas, 0, filtered_criteria_values, 
                     where=[not np.isnan(cv) for cv in filtered_criteria_values], 
                     color='blue', alpha=0.3, label='Kulbak Criteria Values Area')
    
    # Заповнення області для Criteria Values (Working Area)
    plt.fill_between(deltas, 0, filtered_criteria_values_work_area, 
                     where=[not np.isnan(cva) for cva in filtered_criteria_values_work_area], 
                     color='green', alpha=0.3, label='Working Area')

    # Виділення області точного збігання значень
    plt.fill_between(deltas, 0, overlap_exact, 
                     where=[not np.isnan(oe) for oe in overlap_exact], 
                     color='red', alpha=0.5, label='Exact Match Area')
    
    # Лінія для оптимальної delta
    plt.axvline(x=optimal_delta, color='red', linestyle='--', label=f'Optimal Delta = {optimal_delta}')

    plt.xlabel("Delta")
    plt.ylabel("Kulbak Criteria Value")
    plt.title("Dependency of Kulbak Criteria Values on Delta (with Exact Match Area)")
    plt.legend()
    plt.grid(True)
    plt.show()

    print("Optimal delta: ", optimal_delta)
    return optimal_delta

def find_class_optimal_radius(etalon_vectors, binary_matrices):
    # Пошук класів сусідів
    neighbor_pairs = find_neighbors(etalon_vectors)
    # Пошук інформаційного критерію
    criteria_results = compute_criteria(etalon_vectors, binary_matrices, neighbor_pairs)

    # Масив для збереження оптимальних радіусів для кожного класу
    class_radius = []
    print("Calculation of radius for classes")
    for i, result in enumerate(criteria_results):
        # Масиви для використання в графіку залежності критерію Кульбака від радіусу
        # Для кожного класу
        is_working_area_set = []
        radiuses = []
        criteria_result_set = []

        print("Class ", class_names[i])
        print("Is working area | radius | criteria value")

        best_radius = -1
        best_value = -1
        # Проходимо по всім радіусам та знаходимо оптимальний
        for j, pair in enumerate(result):
            is_working_area_set.append(pair[1])
            radiuses.append(j)
            criteria_result_set.append(pair[0])
            print(pair[1], j, pair[0])
            if pair[1] and pair[0] > best_value:
                best_value = pair[0]
                best_radius = j
        if best_radius == -1:
            best_radius = 1  # Якщо не знайдено, використовуємо мінімальний радіус

        # Основна область критерію
        plt.fill_between(radiuses, criteria_result_set, color="skyblue", alpha=0.4, label="Kulbak Criteria Value")
        plt.plot(radiuses, criteria_result_set, color="blue", label="Kulbak Criteria Value (line)")
        
        # Область робочої зони
        working_radiuses = np.array(radiuses)[is_working_area_set]
        working_criteria = np.array(criteria_result_set)[is_working_area_set]
        plt.fill_between(working_radiuses, working_criteria, color="green", alpha=0.3, label="Working Area")
        
        # Відображаємо оптимальний радіус на графіку
        plt.axvline(x=best_radius, color="red", linestyle="--", label=f"Optimal Radius = {best_radius}")
        
        plt.title(f"Dependency of Kulbak Criteria Values on Radius for Class {class_names[i]}")
        plt.xlabel("Radius")
        plt.ylabel("Kulbak Criteria Value")
        plt.legend()
        plt.grid()
        plt.show()

        class_radius.append(best_radius)

    return class_radius

# Функція екзамену зображення
def exam_algorithm(big_image_path, colors, block_size, delta, control_tolerance_vector, etalon_vectors, radius):
    # Завантаження зображення
    image = cv2.imread(big_image_path)
    image_height, image_width, _ = image.shape

    # Створення копії для відображення результатів класифікації
    output_image = image.copy()

    # Встановлення параметрів шрифту
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 0.7
    font_thickness = 2

    # Проходимо по кожній області (квадрат) в зображенні
    for i in range(0, image_width, block_size):
        for j in range(0, image_height, block_size):
            try:
                # Вирізаємо область та класифікуємо її
                crop = image[j:j + block_size, i:i + block_size]
                crop = cv2.cvtColor(crop, cv2.COLOR_BGR2RGB)
                crop_values = image_to_array_from_crop(crop)
                crop_binary_matrix = create_binary_matrix(crop_values, control_tolerance_vector, delta)

                class_index = -1
                highest_value = 0

                # Проводимо порівняння області з еталонами кожного класу
                for k, reference_vector in enumerate(etalon_vectors):
                    result = examine_region(reference_vector, radius[k], crop_binary_matrix)
                    if result > highest_value:
                        class_index = k
                        highest_value = result

                # Додаємо текст
                text_position = (i + 3, j + 20)
                # Якщо область класифікована, позначаємо її номером класу та кольором
                if class_index != -1:
                    # У текст додаємо 
                    cv2.putText(output_image, class_names[class_index], text_position, font, font_scale,
                                colors[class_index], font_thickness)

                    # Малюємо прямокутник навколо області
                    top_left = (i + 1, j + 1)
                    bottom_right = (i + block_size - 1, j + block_size - 1)
                    cv2.rectangle(output_image, top_left, bottom_right, colors[class_index], 3)
                else:
                    cv2.putText(output_image, "N/I", text_position, font, font_scale,
                                colors[4], font_thickness)
                    
                    # Малюємо прямокутник навколо області
                    top_left = (i + 1, j + 1)
                    bottom_right = (i + block_size - 1, j + block_size - 1)
                    cv2.rectangle(output_image, top_left, bottom_right, colors[4], 3)

            except Exception as e:
                print(e)

    output_image = cv2.cvtColor(output_image, cv2.COLOR_BGR2RGB)
    # Збереження результатів класифікації
    cv2.imwrite(output_path, output_image)
    print(f"Success! Classified image saved to {output_path}.")

def extract_pixel_values(images):
    # Завантажуємо зображення класів і перетворюємо їх у масиви пікселів
    pixel_values = []
    for image, class_name in zip(images, class_names):
        pixel_values.append(image_to_array(image, class_name))
    return pixel_values

# Функція перетворення зображення у масив пікселів
def image_to_array(image_path, class_name):
    # відкриваємо зображення
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # Виводимо кожне зображення класів
    fig, ax = plt.subplots(1)
    ax.set_title("Class " + class_name)
    ax.imshow(image)
    return image_to_array_from_crop(image)

# Функція перетворення об'єкту зображення у масив пікселів (RGB)
def image_to_array_from_crop(image):
    # Отримуємо висоту, ширину та кількість каналів зображення
    height, width, channels = image.shape
    # Перетворюємо на потрібний формат
    return image.reshape(height, width * channels)

def examine_region(etalon_vector, radius, binary_matrix):
    # Порівняння області з еталонним вектором
    if radius == 0:
        return 0  # Уникаємо ділення на нуль
    result = np.mean([1 - (calculate_vector_distance(etalon_vector, binary_row) / radius)
                     for binary_row in binary_matrix])
    return result

# Функція отримання контрольних допусків
def find_control_tolerance_vector(pixel_values):
    return [np.mean([row[i] for row in pixel_values]) for i in range(len(pixel_values[0]))]

# Функція отримання бінарної матриці на основі СКД
def create_binary_matrix(pixel_values, control_tolerance_vector, delta):
    return [
        [1 if control_tolerance_vector[i] - delta <= value <= control_tolerance_vector[i] + delta 
         else 0 for i, value in enumerate(row)]
        for row in pixel_values]

# Функція отримання еталонного вектору
def create_etalon_vector(binary_matrix):
    return [int(np.round(np.mean([row[i] for row in binary_matrix]))) for i in range(len(binary_matrix[0]))]

# Функція пошуку пар сусідніх класів для кожного класу
def find_neighbors(etalon_vectors):
    # Знаходимо пари сусідніх класів для кожного класу
    neighbor_pairs = [[len(etalon_vectors[0]) + 1, len(etalon_vectors[0]) + 1] for _ in etalon_vectors]
    for i, vector_1 in enumerate(etalon_vectors):
        for j, vector_2 in enumerate(etalon_vectors):
            if i != j: # якщо класи відрізняються
                # шукаємо відстань між 2 класами
                distance = calculate_vector_distance(vector_1, vector_2)
                # якщо дистанція є меншою за існуючий результат
                if distance < neighbor_pairs[i][1]:
                    # змінюємо результат на новий
                    neighbor_pairs[i] = [j, distance]
    # виводимо фінальний результат знаходження класів-сусідів
    print("Base class | Neighbor class | Distance")
    for i, (j, distance) in enumerate(neighbor_pairs):
        print(f"{class_names[i]} \t   | {class_names[j]} \t\t    | {distance}")
    return neighbor_pairs

# Функція обчислення відстані між двома векторами
def calculate_vector_distance(vector_1, vector_2):
    return np.sum(np.abs(np.array(vector_1) - np.array(vector_2)))

 # Функція обчислення значення критерію для кожного класу і радіуса
def compute_criteria(etalon_vectors, binary_matrices, neighbor_pairs):
    # Ініціалізуємо масив отриманих критеріїв
    criteria_results = [[] for _ in etalon_vectors]

    for class_number in range(len(etalon_vectors)):
        for radius in range(101):
            # Кодова відстань для базового класу
            sk = [calculate_vector_distance(etalon_vectors[class_number], binary_row) 
                for binary_row in binary_matrices[class_number]]
            # Кодова відстань для класу-сусіда
            sk_para = [calculate_vector_distance(etalon_vectors[class_number], binary_row) 
                for binary_row in binary_matrices[neighbor_pairs[class_number][0]]]
            # Перша достовірність
            d1 = np.mean([1 if distance <= radius else 0 for distance in sk])
            # Помилка другого роду
            beta = np.mean([1 if distance <= radius else 0 for distance in sk_para])
            # Помилка першого роду
            alpha = 1 - d1
            # Друга достовірність
            d2 = 1 - beta
            # пошук значення критерію Кульбака
            criteria_value = calculate_kulbak(alpha, beta, d1, d2) / calculate_kulbak(0, 0, 1, 1)
            # Перевірка, чи лежить отримане значення в межах робочої області
            is_within_working_area = d1 >= 0.5 > beta
            criteria_results[class_number].append((criteria_value, is_within_working_area))

    return criteria_results

# Функція розрахунку критерію Кульбака
def calculate_kulbak(alpha, beta, d1, d2):
    return (0.5 * np.log2((d1 + d2 + 10 ** (-kulbak_lambda)) / (alpha + beta + 10 ** (-kulbak_lambda)))) * ((d1 + d2) - (alpha + beta))

# початок розпізнавання
startRecognition(big_image, image_filenames, class_colors, class_block_size)
# Out:
# Calculation of the optimal delta
# For delta 1
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 1  |  0.6918399166297614  |  0.44183991662976146
# For delta 2
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 2  |  0.7544034205718764  |  0.5044034205718763
# For delta 3
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 3  |  0.8254470781841582  |  0.5754470781841582
# For delta 4
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 4  |  0.8375557183027046  |  0.5875557183027046
# For delta 5
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 5  |  0.8522867002352486  |  0.6022867002352486
# For delta 6
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 1
# Delta | criteria value | criteria value in working area
# 6  |  0.861043112715748  |  0.611043112715748
# For delta 7
# Base class | Neighbor class | Distance
# A 	   | B 		    | 35
# B 	   | C 		    | 0
# C 	   | B 		    | 0
# D 	   | B 		    | 3
# Delta | criteria value | criteria value in working area
# 7  |  0.6890518948864701  |  0.09452594744323509
# For delta 8
# Base class | Neighbor class | Distance
# A 	   | C 		    | 71
# B 	   | C 		    | 1
# C 	   | B 		    | 1
# D 	   | B 		    | 3
# Delta | criteria value | criteria value in working area
# 8  |  0.5398021695494974  |  0.16870125303328948
# For delta 9
# Base class | Neighbor class | Distance
# A 	   | D 		    | 106
# B 	   | C 		    | 2
# C 	   | B 		    | 2
# D 	   | B 		    | 12
# Delta | criteria value | criteria value in working area
# 9  |  0.5879173080305546  |  0.22687419531480676
# For delta 10
# Base class | Neighbor class | Distance
# A 	   | D 		    | 106
# B 	   | C 		    | 3
# C 	   | B 		    | 3
# D 	   | C 		    | 23
# Delta | criteria value | criteria value in working area
# 10  |  0.6032449457481639  |  0.37110091651620797
# For delta 11
# Base class | Neighbor class | Distance
# A 	   | D 		    | 107
# B 	   | C 		    | 8
# C 	   | B 		    | 8
# D 	   | C 		    | 32
# Delta | criteria value | criteria value in working area
# 11  |  0.4735197804139987  |  0.371100916516208
# For delta 12
# Base class | Neighbor class | Distance
# A 	   | D 		    | 101
# B 	   | C 		    | 11
# C 	   | B 		    | 11
# D 	   | C 		    | 42
# Delta | criteria value | criteria value in working area
# 12  |  0.47002030955833096  |  0.4466313984476936
# For delta 13
# Base class | Neighbor class | Distance
# A 	   | D 		    | 87
# B 	   | C 		    | 11
# C 	   | B 		    | 11
# D 	   | C 		    | 52
# Delta | criteria value | criteria value in working area
# 13  |  0.4645112292900738  |  0.4186655243385954
# For delta 14
# Base class | Neighbor class | Distance
# A 	   | D 		    | 78
# B 	   | C 		    | 14
# C 	   | B 		    | 14
# D 	   | C 		    | 58
# Delta | criteria value | criteria value in working area
# 14  |  0.5000010453157708  |  0.4613129351092026
# For delta 15
# Base class | Neighbor class | Distance
# A 	   | D 		    | 69
# B 	   | C 		    | 23
# C 	   | B 		    | 23
# D 	   | C 		    | 58
# Delta | criteria value | criteria value in working area
# 15  |  0.6187407856580411  |  0.6187407856580411
# For delta 16
# Base class | Neighbor class | Distance
# A 	   | D 		    | 61
# B 	   | C 		    | 29
# C 	   | B 		    | 29
# D 	   | A 		    | 61
# Delta | criteria value | criteria value in working area
# 16  |  0.6790181991844138  |  0.6790181991844138
# For delta 17
# Base class | Neighbor class | Distance
# A 	   | D 		    | 57
# B 	   | C 		    | 35
# C 	   | B 		    | 35
# D 	   | A 		    | 57
# Delta | criteria value | criteria value in working area
# 17  |  0.8375557183027046  |  0.8375557183027046
# For delta 18
# Base class | Neighbor class | Distance
# A 	   | D 		    | 51
# B 	   | C 		    | 38
# C 	   | B 		    | 38
# D 	   | A 		    | 51
# Delta | criteria value | criteria value in working area
# 18  |  0.7589810090330118  |  0.7589810090330118
# For delta 19
# Base class | Neighbor class | Distance
# A 	   | D 		    | 46
# B 	   | C 		    | 45
# C 	   | B 		    | 45
# D 	   | A 		    | 46
# Delta | criteria value | criteria value in working area
# 19  |  0.7918002038008567  |  0.7918002038008567
# For delta 20
# Base class | Neighbor class | Distance
# A 	   | D 		    | 38
# B 	   | C 		    | 46
# C 	   | B 		    | 46
# D 	   | A 		    | 38
# Delta | criteria value | criteria value in working area
# 20  |  0.7113129351092027  |  0.7012998304390254
# For delta 21
# Base class | Neighbor class | Distance
# A 	   | D 		    | 30
# B 	   | C 		    | 50
# C 	   | B 		    | 50
# D 	   | A 		    | 30
# Delta | criteria value | criteria value in working area
# 21  |  0.6992663421359817  |  0.6937847604749423
# For delta 22
# Base class | Neighbor class | Distance
# A 	   | D 		    | 21
# B 	   | C 		    | 51
# C 	   | B 		    | 51
# D 	   | A 		    | 21
# Delta | criteria value | criteria value in working area
# 22  |  0.7267720518364236  |  0.6937847604749423
# For delta 23
# Base class | Neighbor class | Distance
# A 	   | D 		    | 11
# B 	   | C 		    | 54
# C 	   | B 		    | 54
# D 	   | A 		    | 11
# Delta | criteria value | criteria value in working area
# 23  |  0.7639074573425022  |  0.6937847604749423
# For delta 24
# Base class | Neighbor class | Distance
# A 	   | D 		    | 10
# B 	   | C 		    | 54
# C 	   | B 		    | 54
# D 	   | A 		    | 10
# Delta | criteria value | criteria value in working area
# 24  |  0.7080486164711814  |  0.6474299563742475
# For delta 25
# Base class | Neighbor class | Distance
# A 	   | D 		    | 8
# B 	   | C 		    | 57
# C 	   | B 		    | 57
# D 	   | A 		    | 8
# Delta | criteria value | criteria value in working area
# 25  |  0.7314517837759422  |  0.6662555352178727
# For delta 26
# Base class | Neighbor class | Distance
# A 	   | D 		    | 4
# B 	   | C 		    | 59
# C 	   | B 		    | 59
# D 	   | A 		    | 4
# Delta | criteria value | criteria value in working area
# 26  |  0.6912236133837679  |  0.621100916516208
# For delta 27
# Base class | Neighbor class | Distance
# A 	   | D 		    | 4
# B 	   | C 		    | 61
# C 	   | B 		    | 61
# D 	   | A 		    | 4
# Delta | criteria value | criteria value in working area
# 27  |  0.6734600587683638  |  0.621100916516208
# For delta 28
# Base class | Neighbor class | Distance
# A 	   | D 		    | 4
# B 	   | C 		    | 67
# C 	   | B 		    | 67
# D 	   | A 		    | 4
# Delta | criteria value | criteria value in working area
# 28  |  0.6440869040361052  |  0.6022867002352486
# For delta 29
# Base class | Neighbor class | Distance
# A 	   | D 		    | 1
# B 	   | C 		    | 70
# C 	   | B 		    | 70
# D 	   | A 		    | 1
# Delta | criteria value | criteria value in working area
# 29  |  0.705569060158983  |  0.611043112715748
# For delta 30
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 75
# C 	   | A 		    | 75
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 30  |  0.6751114366054092  |  0.5875557183027046
# For delta 31
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 84
# C 	   | A 		    | 66
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 31  |  0.6624628137272781  |  0.581231406863639
# For delta 32
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 84
# C 	   | A 		    | 62
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 32  |  0.6508941563683164  |  0.5754470781841582
# For delta 33
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 81
# C 	   | A 		    | 61
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 33  |  0.6402453937351198  |  0.5701226968675599
# For delta 34
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 82
# C 	   | A 		    | 56
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 34  |  0.5902095632621516  |  0.5451047816310758
# For delta 35
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 84
# C 	   | A 		    | 52
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 35  |  0.5511687628237775  |  0.5255843814118888
# For delta 36
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 80
# C 	   | A 		    | 49
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 36  |  0.5387324787033794  |  0.5
# For delta 37
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 79
# C 	   | A 		    | 45
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 37  |  0.5350563492685207  |  0.5
# For delta 38
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 77
# C 	   | A 		    | 38
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 38  |  0.4635835126870505  |  0.44378476047494225
# For delta 39
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 78
# C 	   | A 		    | 32
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 39  |  0.436054287429981  |  0.41625553521787273
# For delta 40
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 82
# C 	   | A 		    | 25
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 40  |  0.3525858582308709  |  0.33755571830270453
# For delta 41
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 87
# C 	   | A 		    | 19
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 41  |  0.2825720556146589  |  0.25
# For delta 42
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 89
# C 	   | A 		    | 15
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 42  |  0.3078012332945029  |  0.25
# For delta 43
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 88
# C 	   | A 		    | 13
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 43  |  0.2878072696029267  |  0.25
# For delta 44
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 90
# C 	   | A 		    | 11
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 44  |  0.2945013660359458  |  0.25
# For delta 45
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 90
# C 	   | A 		    | 10
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 45  |  0.29056119404994263  |  0.25
# For delta 46
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 94
# C 	   | A 		    | 6
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 46  |  0.36134198058409817  |  0.25
# For delta 47
# Base class | Neighbor class | Distance
# A 	   | D 		    | 0
# B 	   | C 		    | 97
# C 	   | A 		    | 2
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 47  |  0.3832456063425732  |  0.25
# For delta 48
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 99
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 48  |  0.43908923871148275  |  0.34452594744323506
# For delta 49
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 98
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 49  |  0.4251114366054092  |  0.3375557183027046
# For delta 50
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 98
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 50  |  0.3902453937351199  |  0.32012269686755995
# For delta 51
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 98
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 51  |  0.36270080328548815  |  0.3063504016427441
# For delta 52
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 95
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 52  |  0.32150902911813306  |  0.28575451455906653
# For delta 53
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 91
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 53  |  0.3058219048660388  |  0.2779109524330194
# For delta 54
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 86
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 54  |  0.3058219048660388  |  0.2779109524330194
# For delta 55
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 84
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 55  |  0.292636217655906  |  0.25
# For delta 56
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 82
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 56  |  0.2724574994466341  |  0.25
# For delta 57
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 78
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 57  |  0.2673245963633649  |  0.25
# For delta 58
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 72
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 58  |  0.2629109805426888  |  0.25
# For delta 59
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 71
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 59  |  0.2561141986441453  |  0.25
# For delta 60
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 69
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 60  |  0.25368292621642885  |  0.25
# For delta 61
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 68
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 61  |  0.2518730838433745  |  0.25
# For delta 62
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 66
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 62  |  0.2506728932896952  |  0.25
# For delta 63
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 60
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 63  |  0.2502988678683502  |  0.25
# For delta 64
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 58
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 64  |  0.2500746876500253  |  0.25
# For delta 65
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 58
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 65  |  0.25  |  0.25
# For delta 66
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 55
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 66  |  0.25  |  0.25
# For delta 67
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 54
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 67  |  0.25  |  0.25
# For delta 68
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 53
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 68  |  0.25  |  0.25
# For delta 69
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 51
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 69  |  0.25  |  0.25
# For delta 70
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 50
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 70  |  0.25  |  0.25
# For delta 71
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 49
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 71  |  0.25  |  0.25
# For delta 72
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 47
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 72  |  0.25  |  0.25
# For delta 73
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 46
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 73  |  0.25  |  0.25
# For delta 74
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 45
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 74  |  0.25  |  0.25
# For delta 75
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 43
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 75  |  0.25  |  0.25
# For delta 76
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 39
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 76  |  0.25  |  0.25
# For delta 77
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 36
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 77  |  0.25  |  0.25
# For delta 78
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 30
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 78  |  0.25  |  0.25
# For delta 79
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 27
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 79  |  0.25  |  0.25
# For delta 80
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 22
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 80  |  0.08755571830270455  |  0.08755571830270455
# For delta 81
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 17
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 81  |  0.02558438141188872  |  0.02558438141188872
# For delta 82
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 13
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 82  |  0.0303758632298209  |  -1
# For delta 83
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 9
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 83  |  0.06519624855806946  |  -1
# For delta 84
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 8
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 84  |  0.08755571830270459  |  -1
# For delta 85
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 6
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 85  |  0.07012269686755994  |  -1
# For delta 86
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 4
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 86  |  0.09452594744323507  |  -1
# For delta 87
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 4
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 87  |  0.08755571830270459  |  -1
# For delta 88
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 2
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 88  |  0.08123140686363904  |  -1
# For delta 89
# Base class | Neighbor class | Distance
# A 	   | C 		    | 0
# B 	   | A 		    | 1
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 89  |  0.07012269686755994  |  -1
# For delta 90
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 90  |  0.13039249711613893  |  0.06519624855806946
# For delta 91
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 91  |  0.11270080328548816  |  0.056350401642744075
# For delta 92
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 92  |  0.08360040760171343  |  0.041800203800856715
# For delta 93
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 93  |  0.0607517264596418  |  0.0303758632298209
# For delta 94
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 94  |  0.03873247870337934  |  -1
# For delta 95
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 95  |  0.022457499446634124  |  -1
# For delta 96
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 96  |  0.012910980542688757  |  -1
# For delta 97
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 97  |  0.009183144504021613  |  -1
# For delta 98
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 98  |  0.0036829262164288683  |  -1
# For delta 99
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 99  |  0.00270116223508914  |  -1
# For delta 100
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 100  |  0.0006728932896952746  |  -1
# For delta 101
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 101  |  0.00029886786835020855  |  -1
# For delta 102
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 102  |  7.468765002527866e-05  |  -1
# For delta 103
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 103  |  7.468765002527866e-05  |  -1
# For delta 104
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 104  |  7.468765002527866e-05  |  -1
# For delta 105
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 105  |  0.0  |  -1
# For delta 106
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 106  |  0.0  |  -1
# For delta 107
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 107  |  0.0  |  -1
# For delta 108
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 108  |  0.0  |  -1
# For delta 109
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 109  |  0.0  |  -1
# For delta 110
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 110  |  0.0  |  -1
# For delta 111
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 111  |  0.0  |  -1
# For delta 112
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 112  |  0.0  |  -1
# For delta 113
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 113  |  0.0  |  -1
# For delta 114
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 114  |  0.0  |  -1
# For delta 115
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 115  |  0.0  |  -1
# For delta 116
# Base class | Neighbor class | Distance
# A 	   | B 		    | 0
# B 	   | A 		    | 0
# C 	   | A 		    | 0
# D 	   | A 		    | 0
# Delta | criteria value | criteria value in working area
# 116  |  0.0  |  -1
# Optimal delta:  17
# Base class | Neighbor class | Distance
# A 	   | D 		    | 57
# B 	   | C 		    | 35
# C 	   | B 		    | 35
# D 	   | A 		    | 57
# Calculation of radius for classes
# Class  A
# Is working area | radius | criteria value
# False 0 0.0
# False 1 0.0
# False 2 0.0
# False 3 0.0
# False 4 0.00014937530005055744
# False 5 0.0013457865793905495
# False 6 0.0013457865793905495
# False 7 0.00239470883651662
# False 8 0.0037461676867490265
# False 9 0.005402324470178281
# False 10 0.007365852432857737
# False 11 0.012228397288290562
# False 12 0.015135520128756337
# False 13 0.03006027985633273
# False 14 0.03464919272672979
# False 15 0.06319727345350844
# False 16 0.07011269853704155
# False 17 0.07011269853704155
# False 18 0.08527243531181189
# False 19 0.08527243531181189
# True 20 0.16720081520342686
# True 21 0.1944723551619252
# True 22 0.209436569008623
# True 23 0.24247464038773595
# True 24 0.28049078747023976
# True 25 0.30178831273663287
# True 26 0.30178831273663287
# True 27 0.30178831273663287
# True 28 0.32492562745455617
# True 29 0.3502228732108182
# True 30 0.40914680094099404
# True 31 0.44417245086299173
# True 32 0.5897198254969898
# True 33 0.5897198254969898
# True 34 0.5897198254969898
# True 35 0.775139041899769
# True 36 0.775139041899769
# True 37 1.0
# True 38 0.7751390418997691
# True 39 0.7751390418997691
# True 40 0.5897198254969899
# True 41 0.5897198254969899
# True 42 0.5317869538968919
# True 43 0.5317869538968919
# True 44 0.5317869538968919
# True 45 0.48440366606483204
# True 46 0.48440366606483204
# True 47 0.40914680094099404
# True 48 0.37810378977294035
# True 49 0.32492562745455617
# True 50 0.28049078747023976
# True 51 0.28049078747023976
# True 52 0.2254016065709763
# True 53 0.1944723551619251
# True 54 0.16720081520342686
# True 55 0.16720081520342686
# True 56 0.16720081520342686
# True 57 0.16720081520342686
# True 58 0.16720081520342686
# True 59 0.143018058236266
# True 60 0.13194916544592508
# True 61 0.1215034529192836
# False 62 0.10233752564755488
# False 63 0.09355564444254938
# False 64 0.09355564444254938
# False 65 0.07011269853704158
# False 66 0.05061253704794632
# False 67 0.05061253704794632
# False 68 0.05061253704794632
# False 69 0.044914998893268256
# False 70 0.03006027985633273
# False 71 0.021926326644157723
# False 72 0.015135520128756337
# False 73 0.015135520128756337
# False 74 0.015135520128756337
# False 75 0.012228397288290584
# False 76 0.009639956482890746
# False 77 0.007365852432857737
# False 78 0.0037461676867490265
# False 79 0.0037461676867490265
# False 80 0.0037461676867490265
# False 81 0.0037461676867490265
# False 82 0.0037461676867490265
# False 83 0.0037461676867490265
# False 84 0.0037461676867490265
# False 85 0.0037461676867490265
# False 86 0.0037461676867490265
# False 87 0.00239470883651662
# False 88 0.0005977357367004173
# False 89 0.00014937530005055744
# False 90 0.00014937530005055744
# False 91 0.00014937530005055744
# False 92 0.00014937530005055744
# False 93 0.0
# False 94 0.0
# False 95 0.0
# False 96 0.0
# False 97 0.0
# False 98 0.0
# False 99 0.0
# False 100 0.0
# Class  B
# Is working area | radius | criteria value
# True 0 0.40914680094099404
# True 1 0.531786953896892
# True 2 0.775139041899769
# True 3 1.0
# True 4 1.0
# True 5 1.0
# True 6 1.0
# True 7 1.0
# True 8 1.0
# True 9 1.0
# True 10 1.0
# True 11 1.0
# True 12 1.0
# True 13 1.0
# True 14 1.0
# True 15 1.0
# True 16 1.0
# True 17 1.0
# True 18 1.0
# True 19 0.665022140871491
# True 20 0.5897198254969899
# True 21 0.48440366606483204
# True 22 0.44417245086299173
# True 23 0.40914680094099404
# True 24 0.37810378977294035
# True 25 0.35022287321081835
# True 26 0.32492562745455617
# True 27 0.26078499423227786
# True 28 0.1944723551619251
# True 29 0.1944723551619251
# True 30 0.15475244082627262
# True 31 0.1215034529192836
# False 32 0.10233752564755488
# False 33 0.08527243531181189
# False 34 0.06319727345350844
# False 35 0.05670217039640948
# False 36 0.044914998893268256
# False 37 0.03959750442421645
# False 38 0.03006027985633273
# False 39 0.021926326644157723
# False 40 0.018366289008043227
# False 41 0.012228397288290584
# False 42 0.012228397288290584
# False 43 0.007365852432857737
# False 44 0.00239470883651662
# False 45 0.00239470883651662
# False 46 0.0013457865793905495
# False 47 0.0013457865793905495
# False 48 0.0013457865793905495
# False 49 0.0013457865793905495
# False 50 0.0005977357367004173
# False 51 0.0
# False 52 0.0
# False 53 0.0
# False 54 0.0
# False 55 0.0
# False 56 0.0
# False 57 0.0
# False 58 0.0
# False 59 0.0
# False 60 0.0
# False 61 0.0
# False 62 0.0
# False 63 0.0
# False 64 0.0
# False 65 0.0
# False 66 0.0
# False 67 0.0
# False 68 0.0
# False 69 0.0
# False 70 0.0
# False 71 0.0
# False 72 0.0
# False 73 0.0
# False 74 0.0
# False 75 0.0
# False 76 0.0
# False 77 0.0
# False 78 0.0
# False 79 0.0
# False 80 0.0
# False 81 0.0
# False 82 0.0
# False 83 0.0
# False 84 0.0
# False 85 0.0
# False 86 0.0
# False 87 0.0
# False 88 0.0
# False 89 0.0
# False 90 0.0
# False 91 0.0
# False 92 0.0
# False 93 0.0
# False 94 0.0
# False 95 0.0
# False 96 0.0
# False 97 0.0
# False 98 0.0
# False 99 0.0
# False 100 0.0
# Class  C
# Is working area | radius | criteria value
# False 0 0.0
# False 1 0.0
# False 2 0.0
# False 3 0.0
# False 4 0.0
# False 5 0.0
# False 6 0.0
# False 7 0.0
# False 8 0.0
# False 9 0.00239470883651662
# False 10 0.005402324470178281
# False 11 0.012228397288290562
# False 12 0.021926326644157723
# False 13 0.03464919272672979
# False 14 0.05061253704794632
# False 15 0.06319727345350844
# False 16 0.08527243531181189
# True 17 0.1319491654459251
# True 18 0.2254016065709763
# True 19 0.28049078747023976
# True 20 0.30178831273663287
# True 21 0.40914680094099404
# True 22 0.48440366606483204
# True 23 0.531786953896892
# True 24 0.6650221408714909
# True 25 0.6650221408714909
# True 26 0.6650221408714909
# True 27 0.775139041899769
# True 28 1.0
# True 29 1.0
# True 30 1.0
# True 31 1.0
# True 32 0.7751390418997691
# True 33 0.5317869538968919
# True 34 0.40914680094099404
# False 35 0.0
# False 36 0.0
# False 37 0.0
# False 38 0.0
# False 39 0.0
# False 40 0.0
# False 41 0.0
# False 42 0.0
# False 43 0.0
# False 44 0.0
# False 45 0.0
# False 46 0.0
# False 47 0.0
# False 48 0.0
# False 49 0.0
# False 50 0.0
# False 51 0.0
# False 52 0.0
# False 53 0.0
# False 54 0.0
# False 55 0.0
# False 56 0.0
# False 57 0.0
# False 58 0.0
# False 59 0.0
# False 60 0.0
# False 61 0.0
# False 62 0.0
# False 63 0.0
# False 64 0.0
# False 65 0.0
# False 66 0.0
# False 67 0.0
# False 68 0.0
# False 69 0.0
# False 70 0.0
# False 71 0.0
# False 72 0.0
# False 73 0.0
# False 74 0.0
# False 75 0.0
# False 76 0.0
# False 77 0.0
# False 78 0.0
# False 79 0.0
# False 80 0.0
# False 81 0.0
# False 82 0.0
# False 83 0.0
# False 84 0.0
# False 85 0.0
# False 86 0.0
# False 87 0.0
# False 88 0.0
# False 89 0.0
# False 90 0.0
# False 91 0.0
# False 92 0.0
# False 93 0.0
# False 94 0.0
# False 95 0.0
# False 96 0.0
# False 97 0.0
# False 98 0.0
# False 99 0.0
# False 100 0.0
# Class  D
# Is working area | radius | criteria value
# False 0 0.0
# False 1 0.0
# False 2 0.0
# False 3 0.0
# False 4 0.0
# False 5 0.0
# False 6 0.0
# False 7 0.0
# False 8 0.0
# False 9 0.0
# False 10 0.0
# False 11 0.0
# False 12 0.0
# False 13 0.0
# False 14 0.0
# False 15 0.0
# False 16 0.0
# False 17 0.0
# False 18 0.0
# False 19 0.00014937530005055744
# False 20 0.00014937530005055744
# False 21 0.00014937530005055744
# False 22 0.00014937530005055744
# False 23 0.00014937530005055744
# False 24 0.00014937530005055744
# False 25 0.00014937530005055744
# False 26 0.00014937530005055744
# False 27 0.0005977357367004173
# False 28 0.0005977357367004173
# False 29 0.0005977357367004173
# False 30 0.0037461676867490265
# False 31 0.007365852432857737
# False 32 0.007365852432857737
# False 33 0.015135520128756337
# False 34 0.015135520128756337
# False 35 0.018366289008043227
# False 36 0.021926326644157723
# False 37 0.025821961085377515
# False 38 0.04491499889326828
# False 39 0.06319727345350844
# False 40 0.06319727345350844
# False 41 0.08527243531181189
# True 42 0.11164380973207759
# True 43 0.1319491654459251
# True 44 0.16720081520342686
# True 45 0.209436569008623
# True 46 0.2254016065709763
# True 47 0.26078499423227786
# True 48 0.28049078747023976
# True 49 0.30178831273663287
# True 50 0.3502228732108182
# True 51 0.32492562745455605
# True 52 0.30178831273663276
# True 53 0.32492562745455605
# True 54 0.26078499423227786
# True 55 0.2254016065709763
# True 56 0.18041912652430314
# True 57 0.143018058236266
# True 58 0.1215034529192836
# True 59 0.08527243531181189
# False 60 0.07011269853704158
# False 61 0.04491499889326828
# False 62 0.025821961085377487
# False 63 0.015135520128756337
# False 64 0.009639956482890727
# False 65 0.009639956482890727
# False 66 0.0037461676867490265
# False 67 0.001345786579390546
# False 68 0.00014937530005055744
# False 69 0.00014937530005055722
# False 70 0.00014937530005055722
# False 71 0.00014937530005055722
# False 72 0.0
# False 73 0.0
# False 74 0.0
# False 75 0.0
# False 76 0.00014937530005055722
# False 77 0.00014937530005055722
# False 78 0.0
# False 79 0.0
# False 80 0.0
# False 81 0.0
# False 82 0.0
# False 83 0.0
# False 84 0.0
# False 85 0.0
# False 86 0.0
# False 87 0.0
# False 88 0.0
# False 89 0.0
# False 90 0.0
# False 91 0.0
# False 92 0.0
# False 93 0.0
# False 94 0.0
# False 95 0.0
# False 96 0.0
# False 97 0.0
# False 98 0.0
# False 99 0.0
# False 100 0.0
# Optimal radius for 4 classes: [37, 3, 28, 50]
# Success! Classified image saved to classified_image.jpg.
